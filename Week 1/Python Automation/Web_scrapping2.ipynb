# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
url="https://economictimes.indiatimes.com/markets/stocks/news"

# %%
headers={
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

# %%
r=requests.get(url,{'headers':headers})

# %%
soup=bs4.BeautifulSoup(r.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html xmlns:g="http://base.google.com/ns/1.0" xmlns:java="java" xmlns:listval="com.indiatimes.cms.utilities.CMSDateUtility" xmlns:nohtml="com.til.utils.CommonUtils" xmlns:valurl="com.times.utilities.CMSWebUtility" xmlns:xhtml="http://www.w3.org/1999/xhtml"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta charset="utf-8"/><title>Stocks in News Today - Latest News on Stocks, Stock in News | The Economic Times</title><link href="/manifest.cms" rel="manifest"/><link href="https://www.google-analytics.com" rel="preconnect"/><link href="https://connect.facebook.net" rel="preconnect"/><link href="https://cm.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://googleads.g.doubleclick.net" rel="preconnect"/><link href="https://img.etimg.com" rel="preconnect"/><link href="https://js.etimg.com" rel="preconnect"/><link href="https://css.etimg.com" rel="preconnect"/><link href="https://economictimes.indiatimes.com" rel="preconnect"/><link href="https://sb.scorecardresearch.com" rel="preconnect"/><link href="https://ade.clmbtech.com" rel="preconnect"/><link href="https://www.googletagservices.com" rel="preconnect"/><link href="https://ads.pubmatic.com" rel="preconnect"/><link href="https://securepubads.g.doubleclick.net" rel="preconnect"/><link href="https://static.clmbtech.com" rel="preconnect"/><link href="https://json.bselivefeeds.indiatimes.com" rel="preconnect"/><link href="https://mcxlivefeeds.indiatimes.com" rel="preconnect"/><link href="https://code.highcharts.com" rel="preconnect"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//connect.facebook.net" rel="dns-prefetch"/><link href="//cm.g.doubleclick.net" rel="dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/><link href="https://img.etimg.com" rel="dns-prefetch"/><link href="//js.etimg.com" rel="dns-prefetch"/><link href="//css.etimg.com" rel="dns-prefetch"/><link href="//economictimes.indiatimes.com" rel="dns-prefetch"/><link href="//sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://ade.clmbtech.com" rel="dns-prefetch"/><link href="https://marketcharts.indiatimes.com" rel="dns-prefetch"/><link href="https://jssocdn.indiatimes.com" rel="dns-prefetch"/><link href="https://jsso.indiatimes.com" rel="dns-prefetch"/><link href="https://static.growthrx.in" rel="dns-prefetch"/><link as="font" crossorigin="anonymous" href="/fonts/faustina-v6-latin-500.woff" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-regular.woff" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-500.woff" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-600.woff" rel="preload"/><link as="font" crossorigin="anonymous" href="/fonts/montserrat-v14-latin-700.woff" rel="preload"/><meta content="21540067693" property="fb:pages"/><link href="https://plus.google.com/117381333622785235969" rel="publisher"/><link href="https://economictimes.indiatimes.com/icons/etfavicon.ico" rel="shortcut icon" type="image/x-icon"/><meta content="117787264903013" property="fb:app_id"/><meta content="556964827" property="fb:admins"/><meta content="Stocks in News Today - Latest News on Stocks, Stock in News | The Economic Times" property="og:title"/><meta content="Stocks in News - Find the latest Stocks in News on The Economic Times. Get Stocks Analysis, News on Stocks and more." property="og:description"/><meta content="The Economic Times" property="og:site_name"/><meta content="website" property="og:type"/><meta content="https://economictimes.indiatimes.com/markets/stocks/news/articlelist/2146843.cms" property="og:url"/><meta content="https://img.etimg.com/photo/65498029.cms" property="og:image"/><link href="https://img.etimg.com/photo/65498029.cms" rel="image_src"/><meta content="https://econom ...
# 				        listContentType = '';
# 				        var buyname = 'markets/stocks/news';
# 				    var intv,intv2;var fo;
# 					objPage = {template:'articlelist'};
# 					var skinningExist = false, subsec2 = '2146842', sloadflag = 1;
# 					var msid = '2146843',pgno = 2, loadflag = 1;
# 					if(msid == '2147477890'){
# 					    window.location.href = 'https://economictimes.indiatimes.com';
# 					}
# 					var msidforprimewidget ='60187373';
# 					</script><script type="text/javascript">var newslistred = "",
# 				newseo = "stocks-in-news-today-latest-news-on-stocks-stock-in-news-the-economic-times";
# 				newseo = newseo ? "/"+ newseo : "";
# 				if(newslistred == "newslist"){
# 				    window.location = newseo+"/newslist/"+msid+".cms";
# 				}
#
# 				</script><link href="https://m.economictimes.com/markets/stocks/news" media="only screen and (max-width: 640px)" rel="alternate"/><link href="https://m.economictimes.com/markets/stocks/news" media="handheld" rel="alternate"/><link href="https://economictimes.indiatimes.com/markets/stocks/news" rel="canonical"/><link href="https://m.economictimes.com/markets/stocks/news/amp_articlelist/2146843.cms" rel="amphtml"/><script type="text/javascript">
# 				    var referrer = document.referrer;
#     				    var pgMsid = '2146843';
#
#     				    if(window.location.href.indexOf('articlelist') != -1 && (pgMsid == '6175976' || pgMsid == '63079086')){
#     				        ga('send','event', 'Temp', 'articlelist Referrer', referrer);
#     				    }
#
# 				 </script><script type="text/javascript">if(typeof geolocation != 'undefined' && geolocation != 1 && geolocation != 5){
# 				var crtg_nid = '4306';
#                     var crtg_cookiename = 'crtg_rta';
#                     var crtg_varname = 'crtg_content';
#                     function crtg_getCookie(c_name){ var i,x,y,ARRCookies=document.cookie.split(";");for(i=0;i<ARRCookies.length;i++){x=ARRCookies[i].substr(0,ARRCookies[i].indexOf("="));y=ARRCookies[i].substr(ARRCookies[i].indexOf("=")+1);x=x.replace(/^\s+|\s+$/g,"");if(x==c_name){return unescape(y);} }return'';}
#                     var crtg_content = crtg_getCookie(crtg_cookiename);
#                     var crtg_rnd=Math.floor(Math.random()*99999999999);
#                     (function(){
#                     var crtg_url=location.protocol+'//rtax.criteo.com/delivery/rta/rta.js?netId='+escape(crtg_nid);
#                     crtg_url +='&cookieName='+escape(crtg_cookiename);
#                     crtg_url +='&rnd='+crtg_rnd;
#                     crtg_url +='&varName=' + escape(crtg_varname);
#                     var crtg_script=document.createElement('script');crtg_script.type='text/javascript';crtg_script.src=crtg_url;crtg_script.async=true;
#                     if(document.getElementsByTagName("head").length>0)document.getElementsByTagName("head")[0].appendChild(crtg_script);
#                     else if(document.getElementsByTagName("body").length>0)document.getElementsByTagName("body")[0].appendChild(crtg_script);
#                     })();
# 				}
# 				// eliminate js plugins
#                 skip = {facebook_js: 1};
#
# 				</script><link href="https://economictimes.indiatimes.com/markets/stocks/news/articlelist/msid-2146843,page-2.cms" rel="next"/><script type="text/javascript">
#
# 					/* ========== MF redirection to actual MF URL ============ */
# 					if(document.querySelector){
# 					var canonicalUrl = document.querySelector('link[rel=canonical]').getAttribute('href'),
# 					links = document.getElementsByTagName("link");
# 					canonicalUrl = canonicalUrl.substr(canonicalUrl.indexOf(':') + 1);
# 				    canonicalUrl = canonicalUrl.replace(/m.economictimes.com/g,"economictimes.indiatimes.com");
# 					(function () {
# 					    var ru = '', cu = canonicalUrl, ls = location.search, lp = location.pathname, et_ = 'economictimes.indiatimes.com';
# 					    if(location.host == et_ && ls.toLowerCase().indexOf('utm') == -1) {
#         					if (cu.indexOf("//" + et_) >= 0 && cu.split(".com")[1] != lp) {
#         						ru = cu + ls;
#         					}
#     					}
#     					if(ru != '') {
#     					    if(typeof localStorage != 'undefined') {
#     						    localStorage.setItem('pageRedirectToCan', window.location.href + ' - ' + document.referrer);
#     						}
#     						document.location.href = ru
#     					}
# 					})();
# 					}
# 					/* ========== Ends MF redirection to actual MF URL ============ */
#
# 				</script><script>(function() {var lh = location.host; if(lh.indexOf('economictimes.com') == -1 && lh.indexOf('india'+'times'+'.com') == -1 && lh.indexOf('archive'+'.org') == -1 && lh.indexOf('webcache' + '.googleusercontent'+ '.com') == -1) { window.location.href = 'https' + '://' + 'economictimes' + '.indiatimes.'+ 'com' + '?frmref=' + location.host }})()</script><iframe height="0" id="__tiluuid_frame" style="display:none" width="0"></iframe><script>
# 		    var __tiluuid = localStorage.getItem('__tiluuid');
#         var __tiluuid_expiry_ms = parseInt(localStorage.getItem('__tiluuid_expiry_ms')) || 1607000000410;
#         if (__tiluuid_expiry_ms <= (new Date()).getTime() || localStorage.getItem('__tiluuid') == null) {
#             function receiveMessage(evt) {
#                 if (evt.origin === 'https://tilanalytics.timesinternet.in') {
#                     if (evt.data && evt.data.__tiluuid) {
#                         __tiluuid = evt.data.__tiluuid;
#                         localStorage.setItem('__tiluuid', __tiluuid);
#                         var isValid = /^[0-9A-F]{8}-[0-9A-F]{4}-4[0-9A-F]{3}-[89AB][0-9A-F]{3}-[0-9A-F]{12}-[0-9]+$/i.test(__tiluuid);
#                         if (isValid) {
#                             localStorage.setItem('__tiluuid_expiry_ms', evt.data.__tiluuid_expiry_ms);
# 							try {
# 							 if (ga){ ga('set', {'dimension57': __tiluuid});}
# 						 	}catch(e) {}
#
#                         }
#                         if (evt.data.reset === true && evt.data.__tiluuid_reset_script_path) {
#                             let reset_tiluuid_element = document.createElement("script");
#                             reset_tiluuid_element.setAttribute("src", (evt.data.__tiluuid_reset_script_path));
#                             document.head.appendChild(reset_tiluuid_element);
#                         }
#                     }
#                 }
#             }
#
#             window.addEventListener('message', receiveMessage, false);
#             document.getElementById("__tiluuid_frame").src = 'https://tilanalytics.timesinternet.in/production/frame-2.1.min.html';
#         }
#
#         var _col_uuid;
#         function setColuuid(){for(var o="_col_uuid=",n=decodeURIComponent(document.cookie).split(";"),t=0;t<n.length;t++){for(var u=n[t];" "==u.charAt(0);)u=u.substring(1);0==u.indexOf(o)&&(_col_uuid=u.substring(o.length,u.length))}};
#         setColuuid();
# 		    </script><!--/tiluuidscript.cmspotime:3--><script id="geo_script" src="https://geoapiet.indiatimes.com/?cb=et" type="text/javascript"></script><script>
# 		    geolocation = window.geoinfo && window.geoinfo.geolocation || '';
# 			if(window.localStorage && localStorage.getItem('temp_geolocation')) {var geolocation = localStorage.getItem('temp_geolocation');}
# 		    function allowGDPR() {
# 		        var flag = false, ginfo = window.geoinfo || {};;
# 		        if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {flag = true;}
# 		        return flag;
# 		    }
# 		    allowGdpr = (function () {
#                 var flag = 0, ginfo = window.geoinfo || {};
#                 // if not EU(5), and (not US(2) if US(2) then not california(CA))
#                 if(window.geolocation && geolocation != 5 && (geolocation != 2 || ginfo.region_code != 'CA')) {
#                     flag = 1;
#                 }
#                 return flag;
# 		    })()
# 		    </script><!--/geolocationscript.cmspotime:4--><script src="https://js.etimg.com/js_monetize/v-64,minify-1.cms" type="text/javascript"></script><script type="text/javascript">
# 	        var urlParams = window.URLSearchParams && new URLSearchParams(window.location.search),
# 	            optParam = urlParams.get && urlParams.get('opt');
#
# 	        var objSec = {template: 'articlelist', msid:'2146843', secNames: ['markets','stocks','news'],secIds:['2147477890','1977021501','2146842','2146843']};
#         var tmplName = tpName = 'articlelist',lang = '',nav_sec1,newHookId,subsec1_value,subsec1_common = '1977021501',newHookId2,subsec2_value,subsec2_common = '2146842';
#
#     	        (function () {
#     	            if (self !== top) {
#     	                var e = function (s) {return document.getElementsByTagName(s)};
#     	                e("head")[0].innerHTML = '<style>*{display:none;}</style>';
#     	                setTimeout(function () {
#             	            e("body")[0].innerHTML = '';
#             	            var hEle = e("html")[0];
#         	                hEle.innerHTML = '<a href="' + self.location + '" target="_blank">economictimes.indiatimes.com</a>';
#                             hEle.className = '';
#                             top.location = self.location;
#                         }, 0);
#     	            }
#                 })();
#
#         var objVc = {version_on:'21.05.22 10:56',js_etsubscription:'1',js_onboarding_popup_sh:'8',js_comments:'111',js_googleslock:'782',js_googlelogin:'57',js_common_buydirect:'750',js_bookmark:'18',js_articleshow_main:'75',css_articleshow_new:'32',js_login:'54',js_datepicker:'2',js_electionsmn:'22',js_push:'57',js_slikeplayernew:'6',css_buydirect:'14',js_tradenow:'19',js_common_wap:'98',js_commonall:'138',lib_login:'https://jssocdn.indiatimes.com/crosswalk/jsso_crosswalk_legacy_0.5.9.min.js',live_tv:'{"onoff_flag":"0","platform":"desktop","sections":["1977021501","1715249553","13352306","5575607","837555174","359241701","13357270","107115","897228639","7771250","1466318837"],"pages":"all","auto_open":"1","default_tv":"1","timePeriod":{"showTimeFlag":false,"fromTime":"","toTime":""}}',global_cube:'0',global_cube_wap:'0',global_cube_faces:'2',global_cube_fullad:'0',global_cube_landingon:'sensex',global_cube_wap_url:'https://m.economictimes.com/iframe_cube.cms',site_sync:'0',adx:'1',amazon_bidding:'0',amazon_tam:'1',amazon_tam_web:'0',js_newsltrpopup:'122',nlExpiry:'864000',nlReloadExpiry:'30',js_primetargeting_popup:'2',js_inappmsg:'3',fan_ads:'0',plan_on_paywall:'0',planEntryPointCache:'3',trackAdCode:'0',ajaxError:'1',oauth:'oauth',planPage:'/plans.cms',planPageTest:'https://economictimes.indiatimes.com/plans.cms',subscriptions:'subscriptions',krypton:'kryptonp',apw:'apw',nlSubscribe:'etsub3'};
#         if(window.location.host == 'economictimes-pp.indiatimes.com') {
# 	        objVc.oauth = 'oauth-pp';
#             objVc.krypton = 'krypton-pp';
#             objVc.subscriptions = 'subscriptions-pp';
#             objVc.apw = 'apw-pp';
# 	    }
#         var objDim = {d52:'nature_of_content',d96:'continuous_paywall_hits',d95:'monthly_article_count',d10:'user_login_status_hit',d54:'content_shelf_life',d98:'daily_paid_article_count',d53:'content_target_audience',d97:'monthly_paid_article_count',d12:'tags_meta_keyword',d56:'degree_of_conten',d11:'content_theme_the_primary_tag',d55:'content_tone',d14:'special_coverage',d58:'et_product_item',d13:'article_publish_time',d16:'video_embed',d15:'audio_embed',d59:'show_paywall_final',d61:'paywall_probability',d60:'paywall_score',d63:'paid_articles_read',d62:'eligibility_paywall_rule',d65:'bureau_articles_read',d20:'platform',d64:'free_articles_read',d23:'author_id',d67:'loyalty',d66:'article_length',d25:'page_template',d24:'syft_initiate_page',d68:'paywall_hits',d27:'site_sub_section',d26:'site_section',d29:'section_id',d28:'prime_deal_code',d70:'us_election_2020',d72:'paywall_experiment',d71:'plan_group_id',d32:'prime_article_read_before_syft',d75:'watchlist_active_status',d34:'content_age',d33:'prime_article_read_before_success',d36:'sign_in_initiation_position',d35:'subscription_method_hit',d37:'user_subscription_status',d1:'et_product',d2:'blocker_type',d3:'user_login_status_hit',d4:'agency',d5:'author_name',d6:'cms_content_publishing_type',d7:'content_personalisation_level',d8:'article_publish_date',d9:'sub_section_name',d40:'freeread',d45:'prime_hp_ui_template',d47:'prime_hp_ui_content_b_color',d46:'prime_hp_ui_content_size',d49:'syft_initiate_position',d48:'content_msid',d92:'last_click_source',d50:'signin_initiate_page',d94:'daily_article_count',d93:'internal_source'};var serverTime = '05.22.2021 10:56:02';var WRInitTime=(new Date()).getTime();
#             (function () {if (self !== top) {var e = function (s) {return document.getElementsByTagName(s)}; e("head")[0].innerHTML = '<style>*{display:none;}</style>'; setTimeout(function () {e("body")[0].innerHTML = ''; var hEle = e("html")[0]; hEle.innerHTML = '<a href="' + self.location + '" target="_blank">economictimes.indiatimes.com</a>'; hEle.className = ''; top.location = self.location; }, 0);}})();
#
#         _log = window.console && console.log ? console.log : function () {};
# 		// Creating Elements for IE : HTML 5 and cross domain checks
# 		(function () { var elem = ["article", "aside", "figure", "footer", "figcaption", "header", "nav", "section", "time"];
#     		for(var i=0; i<=elem.length-1; i++) {document.createElement(elem[i])} var hd = 'indiatimes.com', dd = document.domain,intv,intv2,fo; if (dd != hd && dd.indexOf(hd) != -1) {document.domain = hd} })();
# 		var intv,intv2;var fo;
# 		if(subsec1_value == '1715249553' && subsec2_value == '1052732854'){
# 			subsec1_value = newHookId = '1052732854'; // politicsnation
# 		}else if(subsec1_value == '1715249553' && subsec2_value == '1373380680'){
# 			subsec1_value = newHookId = '1373380680'; // Economy
# 		}
#
# 		if(optParam != "1") {
#
# 	    customDimension = window.customDimension || {};
#
#                 var _gaq = _gaq || [];
#                 var customDimension = customDimension || {};
#                 var analytics_js_path = 'https://www.google-analytics.com/analytics.js';
#                 (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                 })(window,document,'script',analytics_js_path,'ga');
#                 var gaProperty = 'UA-198011-5';
#                 var disableStr = 'ga-disable';
#                 if (document.cookie.indexOf(disableStr + '=true') > -1) { window[disableStr + '-' + gaProperty] = true; }
#
#                 ga('set', 'anonymizeIp', true);
#                 ga('create', gaProperty, 'auto', {'allowLinker': true});
#                 ga('require', 'linker');
#                 ga('linker:autoLink', ['economictimes.com']);
#                 ga('require', 'displayfeatures');
#                 window.optimizely = window.optimizely || [];
#                 window.optimizely.push("activateUniversalAnalytics");
#                 ga('require', 'GTM-WV452H7');
#
#                 (function () {
#                     var a = window.localStorage && localStorage.getItem('et_syftCounter') || '';
#                     a = a && JSON.parse(a) || {};
#                     if(a.beforeSyft && customDimension) {
#                         customDimension.dimension32 = a.beforeSyft;
#                     }
#                     if(a.afterSyft) {
#                         customDimension.dimension33 = a.afterSyft;
#                     }
#                 })()
#
#                 if(customDimension){
#             	    customDimension.dimension25 = "articlelist";
#                     customDimension.dimension26 = "Markets";
#                     customDimension.dimension27 = "Markets/Stocks/News/";
#                     customDimension.dimension29 = "1977021501";
#                     customDimension.dimension48 = "2146843";
#                     customDimension.dimension30 = _col_uuid;
#                     customDimension.dimension57 = __tiluuid;
#
#                 }
#
#
# 	    var trafficSource = '';
# 	    function getjStorageVal(keyName) { var jString = localStorage.getItem("jStorage"), value = ''; try { if(jString) { var objJstorage = JSON.parse(jString); value = objJstorage[keyName] ? objJstorage[keyName] : ''; } } catch (e) {} return value; }
# 		(function () {
# 		    function addZero(num) {return (num >= 0 && num < 10) ? '0' + num : num;}
# 		    try {
#     		    lastClick = getjStorageVal('etu_last_click');
#                 if(!lastClick) {
#                     lastClick = document.referrer.indexOf('indiatimes.com') == -1 ? 'direct_landing_articleshow' : 'other';
#                 }
#                 var dref = document.referrer, wlh = window.location.href.toLowerCase(), wlp = window.location.pathname;
#                 if(/google|bing|yahoo/ig.test(dref)) {trafficSource = 'organic';}
#                 else if(/facebook|linkedin|instagram|twitter/ig.test(dref) || wlh.indexOf('utm_medium=social') != -1) { trafficSource = 'social';}
#                 else if(wlh.indexOf('utm_medium=email') != -1) {trafficSource = 'newsletter'; }
#                 else if(getjStorageVal('etu_source')) { trafficSource = getjStorageVal('etu_source');}
#
#                 if(!trafficSource) {
#                     if(wlp == '/' || wlp == '/default.cms') {trafficSource = 'direct'}
#                     else if(wlp.indexOf('articleshow')) {trafficSource = 'organic'}
#                     else {trafficSource = 'other'}
#                 }
#
#                 var dtObject = new Date(), dt = (dtObject.getFullYear() + '' + addZero(dtObject.getMonth() + 1) + '' + addZero(dtObject.getDate())), key = 'et_article_' + dt;
#                 var articleReadCountToday = (getjStorageVal(key) || []).length;
#                 var articleReadCountMonth = 0;
#                 var paidArticleReadCountMonth = 0;
#                 var jString = localStorage.getItem("jStorage");
#                 try {
#                     if(jString) {
#                         var objJstorage = JSON.parse(jString);
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_article_') != -1}).forEach(function (key) { articleReadCountMonth += getjStorageVal(key).length});
#                         Object.keys(objJstorage).filter(function(key) {return key.indexOf('et_primearticle_') != -1}).forEach(function (key) { paidArticleReadCountMonth += getjStorageVal(key) || 0});
#                     }
# 	            } catch (e) {}
#
#                 var paidArticleReadCountTodayKey = 'et_primearticle_' + dt;
#                 var paidArticleReadCountToday = getjStorageVal(paidArticleReadCountTodayKey) || 0;
#                 var continuousPaywallList = getjStorageVal('et_continuousPaywalled') || [];
#
#         		customDimension.dimension92 = lastClick;
#                 customDimension.dimension93 = trafficSource;
#                 customDimension.dimension94 = articleReadCountToday;
#                 customDimension.dimension95 = articleReadCountMonth;
#                 customDimension.dimension96 = continuousPaywallList.length;
#                 customDimension.dimension97 = paidArticleReadCountMonth;
#                 customDimension.dimension98 = paidArticleReadCountToday;
# 		    } catch (e) {}
# 		})();
#
#
#                 try {
#                     var cDimension = localStorage.getItem('et_gadimension1');
#     	            if (cDimension) {
#     	                cDimension = JSON.parse(cDimension);
#     	                Object.keys(cDimension).forEach((key, val) => {
#                             customDimension[key] = cDimension[key];
#                         });
#     	            }
#     	        } catch (e) {}
#                 ga('send', 'pageview', customDimension);
#
#
#         		    var newHookId ='1977021501';
#     			    var newHookId2 = '2146842';
#
#     			        if(newHookId == '1715249553' && newHookId2 == '1052732854'){
#     			            newHookId = '1052732854'; // politicsnation
#     			        }else if(newHookId == '1715249553' && newHookId2 == '1373380680'){
#     			            newHookId = '1373380680'; // Economy
#     			        }
#
#
#         			var subsec1_value ='1977021501', subsec1_2value = '2146842';
#
#     			        if(subsec1_value == '1715249553' && subsec1_2value == '1052732854'){
#     			            subsec1_value = '1052732854'; // politicsnation
#     			        }else if(subsec1_value == '1715249553' && subsec1_2value == '1373380680'){
#     			            subsec1_value = '1373380680'; // Economy
#     			        }
#
#
#
#         (function (g, r, o, w, t, h, rx) {
#             g[t] = g[t] || function () {(g[t].q = g[t].q || []).push(arguments)
#             }, g[t].l = 1 * new Date();
#             g[t] = g[t] || {}, h = r.createElement(o), rx = r.getElementsByTagName(o)[0];
#             h.async = 1;h.src = w;rx.parentNode.insertBefore(h, rx)
#         })(window, document, 'script', 'https://static.growthrx.in/js/v2/web-sdk.js', 'grx');
#         grx('init', 'gf999c70d');
#         var grxDimension = {url: window.location.href, title : document.title, referral_url : document.referrer};
#
#
#
#             var subsStatus = '';
#             var jData = JSON.parse(localStorage.getItem('jStorage'));
#             function getCookie(n) {var ne = n + "=", ca = document.cookie.split(';');for (var i=0;i< ca.length;i++){ var c = ca[i]; while (c.charAt(0) == ' ') c = c.substring(1, c.length); if (c.indexOf(ne) == 0) return c.substring(ne.length, c.length); } return null; }
#             (function () {
#                 var b = document.getElementsByTagName('html')[0];
#                 if(ssoid = getCookie('ssoid')) {
#                     try {
#                         grx('userId', ssoid);
#                         var pfuuid = getCookie('pfuuid');
#                         if(pfuuid) { grxDimension['et_uuid'] = pfuuid}
#                         customDimension.dimension3 = 'LOGGEDIN';
#                         var grx_userData = jData['prime_'+getCookie('TicketId')];
#                         grx_userData = grx_userData || {};
#                         var grx_up = grx_userData.permissions || [];
#                         if(grx_up.indexOf("expired_subscription") > -1) {
#                             subsStatus = 'Expired User';
#         		        } else if (grx_up.indexOf("subscribed") > -1 && grx_up.indexOf("cancelled_subscription") > -1 && grx_up.indexOf("can_buy_subscription") > -1) {
#         		            subsStatus = 'Paid User - In Trial';
#         		        } else if(grx_up.indexOf("subscribed") > -1) {
#         		            subsStatus = 'Paid User';
#                             b.classList.add("prime_user");
#         		        } else if(grx_up.indexOf("etadfree_subscribed") > -1) {
#         		            subsStatus = 'Ad Free User';
#         		        } else if (grx_up.length == 0) {
#         		            subsStatus = '-';
#         		        }
#     		        } catch (e) {}
#                 } else {
#                     customDimension.dimension3 = 'NONLOGGEDIN';
#                 }
#                 if(subsStatus == '-' || subsStatus == '' || subsStatus == 'Expired User') {
#                     b.classList.add("free_user");
#                 }
#                 customDimension.dimension37 = subsStatus;
#                 try {
#                     if(window.localStorage && localStorage.getItem) {
#                         var jString = localStorage.getItem("jStorage");
#                         if(jString) {
#                             var objJstorage = JSON.parse(jString), objProf = objJstorage['et_subscription_profile'];
#                             for (var attrname in objProf) { grxDimension[attrname] = objProf[attrname]; }
#                         }
#                     }
#                 }catch(e) {
#                     console.log('Error profile Dimension');
#                 }
#             })()
#
#             if(window.customDimension && window.objDim) {
#                 for(key in customDimension) {
#                     var dimId = 'd' + key.substr(9, key.length);
#                     if(objDim[dimId] && typeof customDimension[key] != 'undefined') { grxDimension[objDim[dimId]] = customDimension[key]; }
#                 }
#             }
#
#         grx('track', 'page_view', grxDimension);
#
#             var _comscore = _comscore || [];
#             _comscore.push({ c1: "2", c2: "6036484"});
#
#             if(window.allowGdpr == 1) {
#                 (function() {
#                     var s = document.createElement('script'), el = document.getElementsByTagName("script")[0]; s.async = true;
#                     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#                     el.parentNode.insertBefore(s, el);
#                 })();
#             }
#
#
#
#                 if(window.allowGdpr == 1) {
#                     (function() {
#             			function pingIbeat() {
#                 			window._pg_endpt=(new Date()).getTime();
#                 			var e = document.createElement('script');
#                 			e.setAttribute('language', 'javascript');
#                 			e.setAttribute('type', 'text/javascript');
#                 			e.setAttribute('async', true);
#                 			var dt = window.dateFormat ? dateFormat(new Date(), '%Y%M%d') : 1;
#                 			var sd = window.objDomain && objDomain.js || '';
#                 			e.setAttribute('src', sd + '/js_ibeat_ext.cms?v=' + dt);
#                 			//e.setAttribute('src', "https://agi-static.indiatimes.com/cms-common/ibeat.min.js");
#                 			document.head.appendChild(e);
#             			}
#             			if(typeof window.addEventListener == 'function') {
#             			    window.addEventListener("load", pingIbeat, false);
#             			} else {
#                 			var oldonload = window.onload;
#                 			window.onload = (typeof window.onload != 'function') ?
#                 			pingIbeat : function() { oldonload(); pingIbeat(); };
#             			}
#             		})();
#                 }
#
#
#         }
# 	    </script><script type="application/ld+json">
#         	    {
#         	        "@context" : "http://schema.org",
#         		  	"@type": "NewsMediaOrganization",
#         		  	"name": "Economic Times",
#         		    "url" : "https://economictimes.indiatimes.com/","sameAs" : [ "https://www.facebook.com/EconomicTimes","https://twitter.com/economictimes","https://plus.google.com/+TheEconomicTimes"],
#         		    "logo": {
#         		      "@type": "ImageObject",
#             	      "url": "https://img.etimg.com/thumb/msid-76939477,width-600,height-60,quality-100/economictimes.jpg",
#         		      "width": 600,
#         		      "height": 60
#         		    }
#         		  }
#             </script></head><body atf300status="1" atf728status="1" btf300status="1" btf728status="1" innov1status="1" mid300status="1" popstatus="0" shoshstatus="0" slug1status="0"><div data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_OP_MKT_STK_Innov1" data-loc="All" data-oop="1" data-size="" id="div-gpt-ad-1386445009452-0-oop1"></div><section id="interAd"></section><div data-adsslot="/7176/Economictimes/ET_ROS_Sticky_160" data-fallback="1" data-loc="All" data-oop="1" data-size="[[160, 600], [120, 600], [125, 600]]" id="ROS_Sticky_160_Fallback" style="position: fixed; top: 0px; left: 0; margin-left: calc((100% - 1003px) / 2 - -1004px);"></div><main class="pageHolder"><div class="primeDW" id="topAd" l1="1977021501" l2="2146842" l3="2146843" lan=""><section id="topAd"><div data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_ATF_MKT_STK_728" data-loc="All" data-oop="0" data-size="[[1003, 90],[970,90],[728, 90]]" id="div-gpt-ad-1481103461078-25"></div></section></div><div class="band clearfix"><div class="contentwrapper bandCont"><div class="band-items band-item-sm" id="S1_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/pid-40,exchange-nse,sortby-value,sortorder-desc.cms" target="_blank">Benchmarks </a></div><div class="values"><a class="wname" href="https://economictimes.indiatimes.com/marketstats/pid-40,exchange-nse,sortby-value,sortorder-desc.cms" target="_blank">Nifty</a><span class="num">15,175.30</span><span class="per cSprite_b green">269.25</span></div></div></div></div><div class="band-items band-item-lg" id="S2_box"><div class="band-item clearfix"><div class="band-content"><div class="head"><a href="https://economictimes.indiatimes.com/marketstats/duration-1d,marketcap-largecap,pageno-1,pid-0,sort-intraday,sortby-percentchange,sortorder-desc.cms" target="_blank">NSE Gainer-Large Cap </a></div><div class="values"><a class="wname" href="/bank-of-baroda/stocks/companyid-12040.cms" target="_blank">Bank of Baroda</a><span class="num">80.80</span><span class="per cSprite_b green">4.3</span></div></div></div></div><div class="S5_box_wrapper"><div class="band-items" id="S5_box"><a data-ga-onclick="Buy Direct - ETMoney#WEB - Click - ICICI Prudential Midcap Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.etmoney.com/mutual-funds/icici-prudential-midcap-direct-plan-growth/15527?utm%20source=economic-times&amp;utm_medium=web&amp;utm_campaign=market-band" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★</span><span class="ratingGrey">★★★</span></div></div><div class="title" title="ICICI Prudential Midcap Direct Plan-Growth">ICICI Prudential Midcap Direct Plan-Growth</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">16.64 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - ETMoney#WEB - Click - ICICI Prudential Credit Risk Fund Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.etmoney.com/mutual-funds/icici-prudential-credit-risk-fund-direct-plan-growth/16718?utm%20source=economic-times&amp;utm_medium=web&amp;utm_campaign=market-band" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★★★</span></div></div><div class="title" title="ICICI Prudential Credit Risk Fund Direct Plan-Growth">ICICI Prudential Credit Risk Fund Direct Plan-Gr..</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">9.22 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - ETMoney#WEB - Click - ICICI Prudential Multicap Fund Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.etmoney.com/mutual-funds/icici-prudential-multicap-fund-direct-plan-growth/15441?utm%20source=economic-times&amp;utm_medium=web&amp;utm_campaign=market-band" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="ratingGrey">★★★★★</span></div></div><div class="title" title="ICICI Prudential Multicap Fund Direct Plan-Growth">ICICI Prudential Multicap Fund Direct Plan-Growt..</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">14.88 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - ETMoney#WEB - Click - ICICI Prudential Smallcap Fund Direct Plan-Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.etmoney.com/mutual-funds/icici-prudential-smallcap-fund-direct-plan-growth/16675?utm%20source=economic-times&amp;utm_medium=web&amp;utm_campaign=market-band" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="rating">★★★</span><span class="ratingGrey">★★</span></div></div><div class="title" title="ICICI Prudential Smallcap Fund Direct Plan-Growth">ICICI Prudential Smallcap Fund Direct Plan-Growt..</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">16.86 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a><a data-ga-onclick="Buy Direct - ETMoney#WEB - Click - ICICI Prudential Asset Allocator Fund (FOF) Direct - Growth - Invest Now - MarketBand#MarketBand - url" href="https://www.etmoney.com/mutual-funds/icici-prudential-asset-allocator-fund-fof-direct-growth/16965?utm%20source=economic-times&amp;utm_medium=web&amp;utm_campaign=scheme-pages" rel="nofollow sponsored" target="_blank"><div class="band-item clearfix"><div class="band-content-left"><div class="head"><span class="lbl">FEATURED FUNDS</span><div class="ratings flr"><span class="ratingGrey">★★★★★</span></div></div><div class="title" title="ICICI Prudential Asset Allocator Fund (FOF) Direct - Growth">ICICI Prudential Asset Allocator Fund (FOF) Dire..</div></div><div class="band-content-right flt"><div class="head lbl">5Y Return</div><div class="values flt"><span class="per cSprite_b green">14.05 %
#                 </span></div><div class="cta flt">Invest Now</div></div></div></a></div></div><div class="band-items grey"><div class="stats_btn"><a class="mktWatch" href="/marketstats/pid-0,pageno-1,sortby-percentchange,sortorder-desc,sort-intraday.cms?marketcap=largecap%252Cmidcap" target="_blank">Market Watch</a><div class="stats_list"></div></div></div></div></div><!--/market_topband_new.cmspotime:3--><header class="header clearfix"><div class="dtc vam logoPart tac"><a href="/" title="The Economic Times"><img alt="The Economic Times" class="dib" height="39" src="https://img.etimg.com/photo/msid-76931895,quality-100/et-logo.jpg" width="407"/></a><a class="sec_logo bigLogo" href="/markets" id="mktLogo" title="ET Markets"><img alt="ET Markets" src="https://img.etimg.com/photo/msid-76931947,quality-100/et-markets-logo.jpg" width="163"/></a><div class="timeEdition tac"><div class="dib prel edition"><span>English Edition</span></div><span> | </span><span class="dib time">22 May, 2021, 10:54 AM IST</span><span> | </span><a class="dib epaper" data-ga-onclick="Web Top Nav Epaper link#Click on Epaper link#url" href="https://epaper.timesgroup.com/" rel="nofollow" target="_blank">E-Paper</a></div></div><div class="flr subSign"><a class="dib subScribe" data-ga-onclick="Subscription Flow#SYFT#ATF - url" href="/plans.cms">Subscribe</a><div class="dib signInOut prel signIn"><a class="signInLink" data-ga-onclick="ET Login#Signin - Sign In - Click#ATF - url" href="javascript:objUser.login()">Sign In</a></div><div class="soWrapper"><a class="hdr_spcl_ofr top_f_us" data-ga-onclick="Subscription Flow#SYFT#HomepageOfferHeader" data-url="https://economictimes.indiatimes.com/plans.cms"><prime_campaign>Special Offer on ET Prime</prime_campaign></a><a class="hdr_spcl_ofr top_e_us" data-ga-onclick="Subscription Flow#SYFT#HomepageOfferHeader" data-url="https://economictimes.com/plans.cms?dc=DEAL20WEB"><prime_campaign>Special Offer on ET Prime</prime_campaign></a><a class="hdr_spcl_ofr top_c_us" data-ga-onclick="Subscription Flow#SYFT#HomepageOfferHeader" data-url="https://economictimes.com/plans.cms?dc=DEAL20WEB"><prime_campaign>Special Offer on ET Prime</prime_campaign></a><!--/prime_campaign.cms?msid=81429572&bannertype=toppotime:3--></div></div></header><div class="srch-container prel"><div class="srch-overlay-div" id="topSearch"><div class="srch-overlay-content"><input autocomplete="off" class="inputBox" data-search-input="" name="ticker_newsearch" placeholder="Search News, Stock Quotes &amp; NAV" type="text" value=""/><div class="srch-btn btn">Search</div><div class="srch-close">+</div></div></div></div><div class="navFixRef"></div><div class="nav_block clr" id="topnavBlk"><nav class="level3 contentwrapper" data-ga-category="ET-TopNav" id="topnav" nav-sec1="Markets"><div class="sections" id="sideMenu"><span class="menuIcon cSprite"></span><nav class="ddNav" id="sideBarNav"></nav></div><div data-ga-action="Home"><a data-ga-onclick="/" href="/">Home</a></div><div data-ga-action="ETPrime"><a class="navP medium cSprite_b" data-ga-onclick="https://economictimes.indiatimes.com/prime" href="https://economictimes.indiatimes.com/prime">ETPrime</a></div><div data-ga-action="Markets" data-id="1977021501"><a class="current" data-ga-onclick="https://economictimes.indiatimes.com/markets" href="https://economictimes.indiatimes.com/markets">Markets</a><div class="subsecnav" id="subsec1977021501"></div></div><div data-ga-action="News" data-id="1715249553"><a data-ga-onclick="https://economictimes.indiatimes.com/news" href="https://economictimes.indiatimes.com/news">News</a><div class="subsecnav" id="subsec1715249553" style="width:615px"></div></div><div data-ga-action="Industry" data-id="13352306"><a data-ga-onclick="https://economictimes.indiatimes.com/industry" href="https://economictimes.indiatimes.com/industry">Industry</a><div class="subsecnav" id="subsec13352306" style="width:818px"></div></div><div data-ga-action="RISE" data-id="5575607"><a data-ga-onclic ...
# 	                .breadCrumb > span{
# 	                padding-top: 8px;
#                     display: inline-block;
# 	                }
# 	            </style></div></div><div id="breakingNews"><div class="contentwrapper prel"><ul class="bnews flt"></ul><div class="nextPrev"><a class="flt prev cSprite"></a><a class="flr next cSprite"></a></div></div></div><section class="section_list" id="pageContent" itemscope="itemscope" itemtype="http://schema.org/ItemList"><h1 class="h1">News</h1><div class="topsearchwidget" xmlns:valurl="com.times.utilities.CMSWebUtility"><span class="headingname">Top Searches:</span><div class="contentDiv"><ul><li><a href="/markets/stocks/recos" target="_blank" title="Top Stock Recommendations">Top Stock Recommendations</a></li><li><a href="/markets/ipos/fpos/all-you-need-to-know-about-ipo-allotment-process/articleshow/72460826.cms" target="_blank" title="IPO Allotment Process">IPO Allotment Process</a></li><li><a href="/indices/sensex_30_companies" target="_blank" title="Sensex">Sensex</a></li><li><a href="/indices/nifty_50_companies" target="_blank" title="Nifty">Nifty</a></li><li><a href="/markets/forex/currency-converter" target="_blank" title="Currency Converter">Currency Converter</a></li><li><a href="/state-bank-of-india/stocks/companyid-11984.cms" target="_blank" title="SBI share price">SBI share price</a></li></ul></div><div class="nexpreslide" data-next-prev=""><p class="lftp"><span class="prevArr"><span class="prevArrInside"></span></span></p><p class="rftp"><span class="nextArr on"><span class="nextArrInside on"></span></span></p></div></div><!--/topsearchwidget.cms?subsec1=1977021501&subsec2=2146842potime:5--><div id="listingTabs"><ul><li class="" data-id="list" data-type="a"><a href="/markets/stocks/news/articlelist/msid-2146843,contenttype-a.cms" onclick="ga('send','event','content Filter','Articles','');">ARTICLES</a></li><li class="" data-type="v" id="etprime_list"><a href="javascript:void(0)" onclick="ga('send','event','content Filter','ET Prime_web','');"><span class="spantxt p_sprite">ET Prime</span></a></li></ul><div class="clr"></div></div><script>
# 									    ga('send','event','content Filter','impression', '');
#
# 									</script><div class="tabdata"><div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="1" itemprop="position"/><a href="/markets/stocks/news/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds/articleshow/82852034.cms"><span class="imgContainer"><img alt="SEC approves Nasdaq proposal to allow IPO alternative to raise funds" class="lazy" data-original="https://img.etimg.com/thumb/msid-82852034,width-160,height-120,imgsize-281270/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a><h3><a data-orefid="p2146843_1" href="/markets/stocks/news/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds/articleshow/82852034.cms" itemprop="url"><meta content="SEC approves Nasdaq proposal to allow IPO alternative to raise funds" itemprop="name"/>SEC approves Nasdaq proposal to allow IPO alternative to raise funds</a></h3><time class="date-format" data-time="May 22, 2021, 10:50 AM IST">May 22, 2021, 10:50 AM IST</time><p>The move is a big breakthrough for the exchange operator that has been pushing for an alternative for companies to raise money.</p></div><div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="2" itemprop="position"/><a href="/markets/stocks/news/dalal-street-gets-a-boost-from-financial-stocks-sensex-ends-nearly-2-higher/articleshow/82850825.cms"><span class="imgContainer"><img alt="Dalal Street gets a boost from financial stocks, Sensex ends nearly 2% higher" class="lazy" data-original="https://img.etimg.com/thumb/msid-82850825,width-160,height-120,imgsize-229903/dalal-street-gets-a-boost-from-financial-stocks-sensex-ends-nearly-2-higher.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a><h3><a data-orefid="p2146843_2" href="/markets/stocks/news/dalal-street-gets-a-boost-from-financial-stocks-sensex-ends-nearly-2-higher/articleshow/82850825.cms" itemprop="url"><meta content="Dalal Street gets a boost from financial stocks, Sensex ends nearly 2% higher" itemprop="name"/>Dalal Street gets a boost from financial stocks, Sensex ends nearly 2% higher</a></h3><time class="date-format" data-time="May 22, 2021, 09:24 AM IST">May 22, 2021, 09:24 AM IST</time><p>The Sensex climbed 975.62 points, or 1.97%, to close at 50,540.48, while the Nifty closed up 269.25 points, or 1.8%, at 15,175.30.</p></div><div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="3" itemprop="position"/><a data-conttype="500" href="/markets/stocks/news/hindujas-hits-to-cut-debt-via-rights-issue-and-land-sale/articleshow/82851689.cms"><span class="imgContainer"><img alt="Hinduja's HITS to cut debt via rights issue and land sale" class="lazy" data-original="https://img.etimg.com/thumb/msid-82851689,width-160,height-120,imgsize-546350/hindujas-hits-to-cut-debt-via-rights-issue-and-land-sale.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a><h3><a data-conttype="500" data-orefid="p2146843_3" href="/markets/stocks/news/hindujas-hits-to-cut-debt-via-rights-issue-and-land-sale/articleshow/82851689.cms" itemprop="url"><meta content="Hinduja's HITS to cut debt via rights issue and land sale" itemprop="name"/>Hinduja's HITS to cut debt via rights issue and land sale</a></h3><time class="date-format" data-time="May 22, 2021, 10:27 AM IST">May 22, 2021, 10:27 AM IST</time><p>The board of NXTDigital last week approved a rights issue of shares to raise up to Rs 300 crore. In October 2020, the company sold shares of Hinduja Leyland Finance for about Rs 100 crore and repaid debt to that extent.</p></div><div class="eachStory" itemprop="itemListElement" items ...
#
#             	function adwidgetslideboxvideo(data,container){
# 					if (data != null) {
# 						var conObj = document.getElementById(container),
# ...
# 						    More Events
# 						    <span class="dbl_arw"></span></a></div></div></div><!--/event_calnew.cms?noofdays=5&theme=newpotime:2--></div><div class="clrwh"></div><div class="forex_cal"><h2>Forex Calculator</h2><div class="fx_container"><div class="flt first"><span>From this Currency</span><select id="fromcur" name="fromcur"><option value="AFA">Afghanistan Afghani</option><option value="ALL">Albanian Lek</option><option value="DZD">Algerian Dinar</option><option value="ADF">Andorran Franc</option><option value="ADP">Andorran Peseta</option><option value="AOA">Angolan Kwanza</option><option value="AON">Angolan New Kwanza</option><option value="ARS">Argentine Peso</option><option value="AMD">Armenian Dram</option><option value="AWG">Aruban Florin</option><option value="AUD">Australian Dollar</option><option value="ATS">Austrian Schilling</option><option value="AZM">Azerbaijani Manat</option><option value="AZN">Azerbaijani New Manat</option><option value="BSD">Bahamian Dollar</option><option value="BHD">Bahraini Dinar</option><option value="BDT">Bangladeshi Taka</option><option value="BBD">Barbados Dollar</option><option value="BEF">Belgian Franc</option><option value="BZD">Belize Dollar</option><option value="BMD">Bermudian Dollar</option><option value="BTN">Bhutan Ngultrum</option><option value="BOB">Bolivian Boliviano</option><option value="BAM">Bosnian Mark</option><option value="BWP">Botswana Pula</option><option value="BRL">Brazilian Real</option><option value="GBP">British Pound</option><option value="BND">Brunei Dollar</option><option value="BGN">Bulgarian Lev</option><option value="BIF">Burundi Franc</option><option value="BYR">Belarusian Ruble</option><option value="XOF">CFA Franc BCEAO</option><option value="XAF">CFA Franc BEAC</option><option value="XPF">CFP Franc</option><option value="KHR">Cambodian Riel</option><option value="CAD">Canadian Dollar</option><option value="CVE">Cape Verde Escudo</option><option value="KYD">Cayman Islands Dollar</option><option value="CLP">Chilean Peso</option><option value="CNY">Chinese Yuan Renminbi</option><option value="COP">Colombian Peso</option><option value="KMF">Comoros Franc</option><option value="CDF">Congolese Franc</option><option value="CRC">Costa Rican Colon</option><option value="HRK">Croatian Kuna</option><option value="CUC">Cuban Convertible Peso</option><option value="CUP">Cuban Peso</option><option value="CYP">Cyprus Pound</option><option value="CZK">Czech Koruna</option><option value="DKK">Danish Krone</option><option value="DJF">Djibouti Franc</option><option value="DOP">Dominican Peso</option><option value="NLG">Dutch Guilder</option><option value="XCD">East Caribbean Dollar</option><option value="XEU">ECU</option><option value="ECS">Ecuador Sucre</option><option value="EGP">Egyptian Pound</option><option value="SVC">El Salvador Colon</option><option value="EEK">Estonian Kroon</option><option value="ETB">Ethiopian Birr</option><option value="EUR">Euro</option><option value="FKP">Falkland Islands Pound</option><option value="FJD">Fiji Dollar</option><option value="FIM">Finnish Markka</option><option value="FRF">French Franc</option><option value="GMD">Gambian Dalasi</option><option value="GEL">Georgian Lari</option><option value="DEM">German Mark</option><option value="GHC">Ghanaian Cedi</option><option value="GHS">Ghanaian New Cedi</option><option value="GIP">Gibraltar Pound</option><option value="XAU">Gold (oz.)</option><option value="GRD">Greek Drachma</option><option value="GTQ">Guatemalan Quetzal</option><option value="GNF">Guinea Franc</option><option value="GYD">Guyanan Dollar</option><option value="HTG">Haitian Gourde</option><option value="HNL">Honduran Lempira</option><option value="HKD">Hong Kong Dollar</option><option value="HUF">Hungarian Forint</option><option value="ISK">Iceland Krona</option><option value="INR">Indian Rupee</option><option value="IDR">Indonesian Rupiah</option><option value="IRR">Iranian Rial</option><option value="IQD">Iraqi Dinar</option><option va ...
#                 border-bottom: 2px solid #CFCFCF;}
#                 .forex_cal h2{font-family: roboto condensed;background: #E6E6E6;
#                 color: #000;font-size: 16px;
#                 margin-bottom: 5px;font-weight: 700;padding: 10px;text-transform: uppercase;}
#                 .forex_cal .flt span{display:block;font-size: 14px;padding-bottom: 5px;}
#
#                 .forex_cal .flt select {
#                 width: 145px;
#                 height: 30px;
#                 line-height: 30px;
#                 background: #FFF;
#                 }
#                 .forex_cal .flt input {
#                 color: #000;
#                 border-radius: 0px;
#                 background: #FFF;
#                 width: 90px;
#                 height: 18px;
#                 line-height: 18px;
#                 }
#                 .forex_cal .first {
#                 width:165px;
#                 }
#                 .forex_cal .fx_container {
#                 padding:10px 10px 25px 10px;
#                 }
#                 .forex_cal .buttonBlue {
#                 padding: 6px 10px
#                 }</style><div class="clrwh"></div><div class="sec_performance"><h2>Sector Performance</h2><div class="heading"><div class="sec_info">Sectors <br/><span style="font-size: 10px;">Mkt. Cap (%chg)</span></div><div class="sec_adv_dec bold">Decline/Advance</div></div><div class="clr"></div><div class="data_container"></div><div class="highlight"><div class="decline_l2"></div><div>&lt; -2%</div><div class="decline_2_0"></div><div>-2% to &lt; 0%</div><div class="no-change"></div><div>0%</div><div class="advance_0_2"></div><div>&gt; 0% to +2%</div><div class="advance_g2"></div><div>&gt; +2%</div><div class="clr"></div></div><div class="clr"></div></div><div class="clrwh"></div><div class="et_speed_update2"><h2>ET Speed</h2><ul onclick="_gaq.push(['_trackEvent','MktBetaV_EtspeedBottom','select','ETSpeedBottomStory1']);"></ul><div class="clr"></div></div></div><div class="clr"></div></div><!--/markets_beta_c2.cmspotime:11--><div class="clr"></div><div class="clr"></div><div class="clr"></div><div data-url="/default_mostpopularwidget.cms?track=ArticleList&amp;subsec=2146843" id="mostPopular"></div><div class="clr clrwh"></div></aside><div class="clrwh"></div><section id="bottomAd" style="margin:auto; width:auto; max-width:1003px;"><div data-adsslot="ET_Markets/ET_Markets_Stocks/ET_ROS_BTF_MKT_STK_728" data-loc="All" data-oop="0" data-size="[[728, 90], [1003, 90]]" id="div-gpt-ad-1386445009452-3"></div></section><div class="clrwh"></div><div class="clr"></div><div class="btmFooter clearfix" data-ga-category="Footer Element Clicks"><div class="bottomBar clearfix"><div class="contentwrapper"><div class="flt"><a href="/" title="The Economic Times"><img alt="The Economic Times" height="28" src="https://img.etimg.com/photo/msid-74462387,quality-100/et-logo.jpg" style="margin-top: 3px;" title="The Economic Times" width="255"/></a></div><div class="btmSearch flt"><input autocomplete="off" class="inputBox" data-search-input="" name="ticker" placeholder="Search News, Stock Quotes &amp; NAV" type="text" value=""/><span class="cSprite_a searchIcon"></span></div></div></div><div class="browseComp" data-ga-action="Browse Companies"><div class="browse"><div class="txt dib tac"><span>Browse</span><span class="sm">Companies:</span></div><div class="list dib"><div><a data-ga-onclick="A - href" href="/markets/stocks/stock-quotes?ticker=a">A</a><a data-ga-onclick="B - href" href="/markets/stocks/stock-quotes?ticker=b">B</a><a data-ga-onclick="C - href" href="/markets/stocks/stock-quotes?ticker=c">C</a><a data-ga-onclick="D - href" href="/markets/stocks/stock-quotes?ticker=d">D</a><a data-ga-onclick="E - href" href="/markets/stocks/stock-quotes?ticker=e">E</a><a data-ga-onclick="F - href" href="/markets/stocks/stock-quotes?ticker=f">F</a><a data-ga-onclick="G - href" href="/markets/stocks/stock-quotes?ticker=g">G</a><a data-ga-onclick="H - href" href="/markets/stocks/stock-quotes?ticker=h">H</a><a data-ga-onclick="I - href" href="/markets/stocks/stock-quotes?ticker=i">I</a><a data-ga-onclick="J - href" href="/markets/stocks/stock-quotes?ticker=j">J</a><a data-ga-onclick="K - href" href="/markets/stocks/stock-quotes?ticker=k">K</a><a data-ga-onclick="L - href" href="/markets/stocks/stock-quotes?ticker=l">L</a><a data-ga-onclick="M - href" href="/markets/stocks/stock-quotes?ticker=m">M</a><a data-ga-onclick="N - href" href="/markets/stocks/stock-quotes?ticker=n">N</a><a data-ga-onclick="O - href" href="/markets/stocks/stock-quotes?ticker=o">O</a><a data-ga-onclick="P - href" href="/markets/stocks/stock-quotes?ticker=p">P</a><a data-ga-onclick="Q - href" href="/markets/stocks/stock-quotes?ticker=q">Q</a><a data-ga-onclick="R - href" href="/markets/stocks/stock-quotes?ticker=r">R</a><a data-ga-onclick="S - href" href="/markets/stocks/stock-quotes?ticker=s">S</a><a data-ga-onclick="T - href" href="/markets/stocks/stock-quotes?ticker=t">T</a><a data-ga-onclick="U - href" href="/markets/stocks/stock-quotes?ticker=u">U</a><a data-ga-onclick="V - href" ...
# 				        var scriptObject = document.createElement('script');
# 				        scriptObject.type = 'text/javascript';
# 				        scriptObject.async = true;
# 				        scriptObject.src = url;
# 				        document.getElementsByTagName('head')[0].appendChild(scriptObject);
# 				    }
#
# 					var page = { msid : '2146843'}
# 					var sharer = {
# 						title:"Stocks in News Today - Latest News on Stocks, Stock in News | The Economic Times",
# 						desc:"Stocks in News - Find the latest Stocks in News on The Economic Times. Get Stocks Analysis, News on Stocks and more.",
# 						url:"https://economictimes.indiatimes.com/markets/stocks/news/articlelist/2146843.cms"
# 					}
# 					var shareURL = "https://economictimes.indiatimes.com/markets/stocks/news/articlelist/2146843.cms";
#
# 					var secName = 'News';
#
# 					</script><script type="text/javascript">
#         	                var utmcampaign_val = 'ETStocklisting_Widget',
#         	                utmcontent_val = 'Widget_ETStocklisting';
#         	            </script><div data-adsslot="ET_ROS_NW/ET_ROS_Andbeyond_1x1" data-loc="All" data-size="[1, 1]" id="div-gpt-ad-1559650249467-0"></div><script type="text/javascript">
# 	    if(optParam != "1") {
#
# 	    try {
# 	        var _page_config;
# 	        var monthName = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'];
#             var IBDate = new Date();
#             var IBDateFmt = function() {
#                 return monthName[IBDate.getMonth()] +' '+IBDate.getDate()+', '+IBDate.getFullYear()+', 12.00 AM IST';
#             }
#             var ibeatDate = ''+ IBDateFmt() +'';
#             var _iBeat_cat = 'Markets', _iBeat_subcat = 'Markets-Stocks', _iBeat_catids = '2147477890,1977021501,2146842,2146843';
#
#             _page_config = {
#                 host : 'economictimes.indiatimes.com',
#     			key : 'f66e70a45a565c9c76a526c5e9e99df',
#     			domain : 'economictimes.indiatimes.com',
#     			channel :  '',
#     			action : 1,
#     			articleId : 2146843,
#     			contentType: 20,
#             	location : 1,
#             	cat : 'Markets',
#     			subcat : 'Markets-Stocks',
#     			contenttag : '',
#     			catIds : '2147477890,1977021501,2146842,2146843',
#     			articledt : ibeatDate,
#     			author : '',
#     			url : window.location.href,
#     			iBeatField : 'undefined'
#             }
#
#
#         } catch (e) {console.error('error', e);}
#
#
# 	    var secname="Markets Stocks News";
# 	   var agename='';
#
#
#
# 	    var _mfq = (_mfq || []), mouseflowPath = '/articlelist';
#
#
#
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({'pageTitle': document.title});
#
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer','GTM-566NCXC');
#
#
#
# 	    }
# 	    window.setColuuid && setColuuid();
# 	    ga('set', {'dimension57': __tiluuid, 'dimension30': _col_uuid});
# 	    </script><script>
#                      function invokeLogin(){
# 						try{
# 						isLoggedSso = getCookievaluetwitt('MSCSAuth');
# 						if(Get_Ckie('autologin')!=null){
# 							Delete_Ckie("autologin","/",".indiatimes.com");
# 						}
# 						tpbar1();
# 						}
# 						catch(ex)
# 						{
# 						}
# 						ga('send', 'event', 'Temp', 'invokeLogin', window.location.href);
# 					}
#
# 				</script><script type="application/ld+json">
#                 {
#                     "@context": "http://schema.org",
#                     "@type": "WebPage",
#                     "name": "Stocks in News Today - Latest News on Stocks, Stock in News | The Economic Times",
#                     "url": "https://economictimes.indiatimes.com/markets/stocks/news",
#                     "description" : "Stocks in News - Find the latest Stocks in News on The Economic Times. Get Stocks Analysis, News on Stocks and more.",
#                     "publisher": {
#                         "@type": "NewsMediaOrganization",
#                         "name": "Economic Times",
#                         "url":  "https://economictimes.indiatimes.com",
#                         "logo": {
#                         "@type": "ImageObject",
#                         "url": "https://img.etimg.com/photo/17952959.cms"
#                         }
#                 }
#             }
#                 </script></body></html>

# %%
soup.findAll('div',{'class':'eachStory'})[0].find('a')
# Out:
# <a href="/markets/stocks/news/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds/articleshow/82852034.cms"><span class="imgContainer"><img alt="SEC approves Nasdaq proposal to allow IPO alternative to raise funds" class="lazy" data-original="https://img.etimg.com/thumb/msid-82852034,width-160,height-120,imgsize-281270/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a>

# %%
content=soup.findAll(class_='eachStory')
print(content)
# Out:
# [<div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="1" itemprop="position"/><a href="/markets/stocks/news/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds/articleshow/82852034.cms"><span class="imgContainer"><img alt="SEC approves Nasdaq proposal to allow IPO alternative to raise funds" class="lazy" data-original="https://img.etimg.com/thumb/msid-82852034,width-160,height-120,imgsize-281270/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a><h3><a data-orefid="p2146843_1" href="/markets/stocks/news/sec-approves-nasdaq-proposal-to-allow-ipo-alternative-to-raise-funds/articleshow/82852034.cms" itemprop="url"><meta content="SEC approves Nasdaq proposal to allow IPO alternative to raise funds" itemprop="name"/>SEC approves Nasdaq proposal to allow IPO alternative to raise funds</a></h3><time class="date-format" data-time="May 22, 2021, 10:50 AM IST">May 22, 2021, 10:50 AM IST</time><p>The move is a big breakthrough for the exchange operator that has been pushing for an alternative for companies to raise money.</p></div>, <div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="2" itemprop="position"/><a href="/markets/stocks/news/dalal-street-gets-a-boost-from-financial-stocks-sensex-ends-nearly-2-higher/articleshow/82850825.cms"><span class="imgContainer"><img alt="Dalal Street gets a boost from financial stocks, Sensex ends nearly 2% higher" class="lazy" data-original="https://img.etimg.com/thumb/msid-82850825,width-160,height-120,imgsize-229903/dalal-street-gets-a-boost-from-financial-stocks-sensex-ends-nearly-2-higher.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a><h3><a data-orefid="p2146843_2" href="/markets/stocks/news/dalal-street-gets-a-boost-from-financial-stocks-sensex-ends-nearly-2-higher/articleshow/82850825.cms" itemprop="url"><meta content="Dalal Street gets a boost from financial stocks, Sensex ends nearly 2% higher" itemprop="name"/>Dalal Street gets a boost from financial stocks, Sensex ends nearly 2% higher</a></h3><time class="date-format" data-time="May 22, 2021, 09:24 AM IST">May 22, 2021, 09:24 AM IST</time><p>The Sensex climbed 975.62 points, or 1.97%, to close at 50,540.48, while the Nifty closed up 269.25 points, or 1.8%, at 15,175.30.</p></div>, <div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="3" itemprop="position"/><a data-conttype="500" href="/markets/stocks/news/hindujas-hits-to-cut-debt-via-rights-issue-and-land-sale/articleshow/82851689.cms"><span class="imgContainer"><img alt="Hinduja's HITS to cut debt via rights issue and land sale" class="lazy" data-original="https://img.etimg.com/thumb/msid-82851689,width-160,height-120,imgsize-546350/hindujas-hits-to-cut-debt-via-rights-issue-and-land-sale.jpg" height="120" src="https://img.etimg.com/thumb/msid-42031747,width-160,height-120/etlogo.jpg" width="160"/></span></a><h3><a data-conttype="500" data-orefid="p2146843_3" href="/markets/stocks/news/hindujas-hits-to-cut-debt-via-rights-issue-and-land-sale/articleshow/82851689.cms" itemprop="url"><meta content="Hinduja's HITS to cut debt via rights issue and land sale" itemprop="name"/>Hinduja's HITS to cut debt via rights issue and land sale</a></h3><time class="date-format" data-time="May 22, 2021, 10:27 AM IST">May 22, 2021, 10:27 AM IST</time><p>The board of NXTDigital last week approved a rights issue of shares to raise up to Rs 300 crore. In October 2020, the company sold shares of Hinduja Leyland Finance for about Rs 100 crore and repaid debt to that extent.</p></div>, <div class="eachStory" itemprop="itemListElement" itemscope="itemscope" itemtype="http: ...

# %%
l=[]
for i in range(0,len(content)):
    l.append(content[i].find('p').text)

# %%
for i in range(0,len(l)):
    print(l[i])
# Out:
# The move is a big breakthrough for the exchange operator that has been pushing for an alternative for companies to raise money.
# The Sensex climbed 975.62 points, or 1.97%, to close at 50,540.48, while the Nifty closed up 269.25 points, or 1.8%, at 15,175.30.
# The board of NXTDigital last week approved a rights issue of shares to raise up to Rs 300 crore. In October 2020, the company sold shares of Hinduja Leyland Finance for about Rs 100 crore and repaid debt to that extent.
# While online retailers and large chains have been forced to delay replenishment of inventory as several employees are off work due to Covid, leading to stock-piling, supermarkets said demand has also been hit due to truncated store timings.
# The credit facilities committee of the board at its meeting held on May 21 has approved the raising of funds up to Rs 150 crore.
# The company's profit after tax has grown three-times to Rs 106 crore in FY20-21, backed by technology adoption and an increase in rural penetration as the company continues to serve the community at large, Shriram Life Insurance Company (SLIC) said in a release.
# Refinitiv Lipper showed US money market funds received a net inflow of $25.34 billion, a four-fold increase over the previous week.
# In an order uploaded on its website on Friday, SAT has directed the closure of the escrow account and permitted the NSE to utilise the amount for the business purposes.
# This week, benchmark indices rose over 3 per cent led by a resurgence of interest in bank stocks as well as fading concerns among investors over corporate earnings growth, which were triggered by the onset of the second Covid-19 wave.
# Veliyath’s purchase accounted for a third of the volume of the stock traded in today’s session.
# The former non-executive director, Pia Johnson, and her husband, Mehul Johnson, violated the Prohibition of Insider Trading (PIT) norms by trading in firm's scrip while in possession of unpublished price-sensitive information (UPSI) when the trading window ought to have been closed.
# This is the second relaxation for Alternative Investment Funds (AIFs) by the capital markets regulator in the past three years. In 2018, it raised the overseas investment limit to $750 million from $500 million.
# IHS Markit's data showed U.S. business activity picked up in May amid strong domestic demand, but backlogs of uncompleted work are piling up as manufacturers struggle to find raw materials and labor.
# The recent volatility in crypto currencies helped bitcoin decline over 50 percent from its peak of $64870 on 14 April 2020 to almost $30000 on 19 May 2021. However, it’s not the first time Bitcoin has corrected over 50 percent from the peak. ET NOW's Jayesh Khilnani with detailed report. Take a look...
# Hindalco Industries NSE 1.19 % today reported a 189 per cent year-on-year rise in its consolidated net profit for the quarter ended March to a record high of Rs 1,928 crore, which was above analysts’ estimates of Rs 1,194.2 crore for the quarter. The company’s board also declared a final dividend of Rs 3 per share for the financial year ended March 2021.
# SBI's extraordinary performance on asset quality as well as surprisingly low slippages of around Rs 5,500 crore bodes well for the stock market’s attempt at reclaiming its record high.
